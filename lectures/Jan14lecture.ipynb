# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Boxplots

# %% [markdown]
# ## Math 318 Style Plotting

# %% [markdown]
# ### Figure and Axes

# %% [markdown]
# ### Using Subplots
