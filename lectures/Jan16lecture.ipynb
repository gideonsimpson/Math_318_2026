# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# # Exporting Data Frames

# %% [markdown]
# # Confidence Intervals

# %% [markdown]
# # Intro to Regression
