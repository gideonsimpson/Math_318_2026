# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# # Linear Regression with One Feature

# %% [markdown]
# ## Generate Data

# %% [markdown]
# ## statsmodels

# %% [markdown]
# ## sklearn
