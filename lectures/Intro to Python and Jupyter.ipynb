# %% [markdown]
# # Basic Arithmetic

# %% [markdown]
# # NumPy

# %% [markdown]
# ## Functions

# %% [markdown]
# ## Arrays and Matrices

# %% [markdown]
# ### Arrays

# %% [markdown]
# ### Matrices

# %% [markdown]
# # Random Variables

# %% [markdown]
# ## Uniform

# %% [markdown]
# ## Gaussian

# %% [markdown]
# ## Setting the Seed

# %% [markdown]
# # LaTeX and Markdown

# %% [markdown]
# # Source Files

# %% [markdown]
# # Elementary Statistics

# %% [markdown]
# # Control Structures in Python

# %% [markdown]
# # Functions

# %% [markdown]
#  # Loading Data and Data Frames
